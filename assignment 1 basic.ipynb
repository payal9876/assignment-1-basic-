# %% [raw]
# 1. In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
#
# 6
#
# ans(1)  values='hello',-87.8,6
# expressions=*,-,/

# %% [raw]
#  2. What is the difference between a string and a variable
# ans(2) The main difference between string and a variable is that string is the plain text which is enclosed in single quotes or double quotes whereas variable is the container which holds the different kind of datatype
# for eg-'payal' this is the string
# x='payal' ,here x is the variable which is holding a string datatype

# %% [raw]
# 3.Describe three different datatypes
# ans(3) the main datatypes in python are
# string,int,floats,Boolean,lists,tuples
# string=string is like the plain text enclosed within single quotes or double quotes
# floats=floats is like the decimal datatype for eg-3.456
# booleans=Truth values that represents by yes or no
# lists=lists is the collection of the data

# %% [raw]
# 4.what is an expression made up of
# what all expressions do
# ans(4) the expression is an combination of operators and operands that is interpreted to produce some other value
# for eg=a*b
# here a and b are the operands and * is the operator and together this make an expression

# %% [raw]
# 5.the assignment statements like spam=10,what is the difference between assignment and statement
# ans(5) here i am assigning the spam variable is equal to 10 ,so this is kind of statement in which i am assigning variable is equal to 10

# %% [raw]
# 6.after running the code what does the variable bacon contain
# bacon=22
# bacon+1
# ans(6) bacon contains the same value as it was before which is 22
# as we are not changing it

# %% [raw]
# 7.what should be the value of these expressions
# 'spam'+'spamspam'
# 'spam'*3
# ans(7) these both expressions have same value which is 'spamspamspam'

# %% [raw]
# 8.what three functions which ca8n be used to get the integer,floating and string version of value
# ans(8) the three functions are int(),str(),float()

# %% [raw]
# 9.why does this expression cause an error
# 'i have eaten' +99+'burritos'
# ans(9) this cause an error because string and integer concateination is not possible
